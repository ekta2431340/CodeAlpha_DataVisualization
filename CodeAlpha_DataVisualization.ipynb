# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/netflix_titles.csv')

# %% [markdown]
# 1. Movies vs TV Shows

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8,5))
sns.countplot(x='type', data=df)
plt.title('Movies vs TV Shows')
# Out:
# Text(0.5, 1.0, 'Movies vs TV Shows')

# %% [markdown]
# 2. Top 10 Countries

# %%
plt.figure(figsize=(12,6))
df['country'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Countries Producing Netflix Content')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# 3. Top Ratings

# %%
plt.figure(figsize=(10,6))
sns.countplot(y='rating', data=df,
order=df['rating'].value_counts().index[:10])
plt.title('Top Ratings on Netflix')
plt.show()

# %% [markdown]
# 4. Content Release Trend

# %%
plt.figure(figsize=(12,6))
df['release_year'].value_counts().sort_index().tail(20).plot()
plt.title('Netflix Content Release Trend')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Insights:
#
# 1. Movies dominate Netflix content.
# 2. USA produces the highest amount of Netflix content.
# 3. TV-MA is one of the most common ratings.
# 4. Netflix content production increased rapidly in recent years.
